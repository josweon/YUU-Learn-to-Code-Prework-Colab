# %%
# duplicate cell

# %% [markdown]
# # Session 1: Getting Started with Code
#
# Today we're going to learn what programming is. Before we do, we're going to familiarize ourselves with **Google Colaboratory**, which is the web-based tool we'll be using throughout these pre-work sessions.
#
# ## Agenda
# 1. **Getting Oriented** (15 minutes): Find our way around Google Colaboratory and run our first cell.
# 2. **New Information – Algorithms, Operators, and Functions** (40–45 minutes): Learn what an algorithm is, how to do arithmetic in code, and write our first program.
# 3. **We Do and Wrap Up** (30 minutes): Hands-on exercises to solidify your understanding.

# %% [markdown]
# ## Part 1: Getting Oriented

# %% [markdown]
# A notebook like this one is made of **cells**. Some cells hold text (like this one), and some hold code that you can run.
#
# Run the cell below two ways: click the run button to its left, then run it again with the keyboard shortcut (**Shift + Enter**).

# %%
2 + 3

# %% [markdown]
# #### Be sure you understand how to run a cell using both the run button and the keyboard shortcut...
# 1. Change the expression in the cell above (e.g., make it subtraction instead of addition, change the numbers, etc.)
# 2. Run it again.

# %% [markdown]
# ### What are the numbers in brackets, e.g., `[1]`?
# * The numbers show the order in which you ran the cells
# * If you go back and re-run a cell, the order can change
# * The *input* to the cell is what you typed, e.g., `2 + 3`, and the *output* from the cell is the result that was generated (`5`, in this case)
# * Not every cell generates output, as we'll see shortly
# * Use the **+Code / +Markdown** buttons to add cells
#   * Let's try them...

# %% [markdown]
# ### One more thing: comments

# %% [markdown]
# * Any line that begins with `#` is a **comment**
#   * The computer ignores it completely
#   * Comments are notes for the humans reading the code
# * Nearly every language has comments, the symbol is just different (`//` is a common one)
# * You'll see comments used throughout these notebooks to explain what a line does

# %%
# This line is a comment. Nothing happens when the computer reaches it.
7 * 6  # comments can also sit at the end of a line of code

# %% [markdown]
# Now that we can run code, let's talk about what programming actually is.

# %% [markdown]
# ## Part 2: New Information – Algorithms, Operators, and Functions

# %% [markdown]
# ### 1. What is Coding/Programming?
# * Converting a problem you want to solve into code which solves that problem
#   * or...turning a **problem statement** into code which will *solve* that problem
# * A *(computer) program* is a set of statements or instructions that tells the computer what to do
# * There's more to it...we'll revisit this definition in the next session

# %% [markdown]
# ### 2. What's an Algorithm?
# * An *algorithm* is a process or set of rules we follow when performing problem-solving operations (usually, but not always, by a computer)
# * It's like a recipe, explaining the steps to solve the problem (e.g., bake a cake)
# * An algorithm is typically something we could give to another human and they would be able to solve the problem themselves without a computer

# %% [markdown]
# #### Let's look at some algorithms
# * An algorithm for converting Fahrenheit temperatures into Celsius:
#   1. Subtract 32 from the Fahrenheit temperature
#   2. Multiply the result by 5/9
# * An algorithm for computing the tip at a restaurant:
#   1. Ask for desired tip rate (20%, 25%, 15%, etc.)
#   2. Multiply the amount of the bill by that percentage
# * An algorithm for washing your dishes:
#   1. Scrub
#   2. Rinse
#   3. Repeat

# %% [markdown]
# #### Programming computers is all about **precision**
# * A computer program needs to contain *precise* rules for the computer to follow, we can't leave out any details or our code won't work
#   * Let's watch a video that will help us understand why precision matters... https://www.youtube.com/watch?v=FN2RM-CHkuI

# %% [markdown]
# ### 3. Operators

# %% [markdown]
# * Let's learn some of the basics of programming, so we can start writing some programs
# * First we'll look at some *operators* which let us perform operations and calculations
#   * Don't worry, you need not be a math whiz to be successful at programming
#   * We'll start with arithmetic problems, so they are familiar, but once we're successful with those, we won't be doing much more of it, and we won't really do anything beyond arithmetic
# * The arithmetic operators are **+**, **-**, **×**, **÷**
#   * The last two aren't on our keyboard, so nearly every language uses `*` for multiplication, and `/` for division

# %% [markdown]
# **Addition and subtraction:**

# %%
5 + 5

# %%
100 - 35

# %% [markdown]
# **Multiplication and division:**

# %%
3 * 19

# %%
33 / 15

# %% [markdown]
# **Parentheses**, for grouping. These work the same way they did in math class:

# %%
(2 + 3) * 4

# %%
# vs. the same numbers without parentheses
2 + 3 * 4

# %% [markdown]
# In addition, we can do exponentiation (a<sup>b</sup>) and compute the modulus, or remainder when performing integer division. Modulus looks unfamiliar now, but it turns out to be one of the most useful operators there is.

# %%
2 ** 5  # exponentiation operator: 2 * 2 * 2 * 2 * 2

# %%
19 % 5  # modulus operator: what is the remainder when dividing 19 by 5

# %%
18 % 3  # what is the remainder when dividing 18 by 3

# %% [markdown]
# * What we've written above are technically *numerical expressions*, and these same expressions would work in many programming languages

# %% [markdown]
# ### 4. Our First Program

# %% [markdown]
# * When learning a new programming language, it's customary to write a ["Hello, World!" program](https://en.wikipedia.org/wiki/%22Hello,_World!%22_program), that is, a program which does nothing more than print "Hello, world!" on the screen

# %% [markdown]
# Type the following into the next cell and then run it
#
# `print('Hello, world!')`

# %% [markdown]
# ### 5. When Code Breaks

# %% [markdown]
# * Code breaks often, and reading the error message is part of the work
# * The cell below is the same program with the quotes left off
#   * Read the error before you fix it
#   * The last line names the problem, and the arrow points at where the computer got confused

# %%
print(Hello, world!)

# %% [markdown]
# Fix it in the cell below and run it again.

# %% [markdown]
# ### 6. Functions

# %% [markdown]
# * We can think of a function as being like an "appliance"
#     * An appliance performs a task for us
#   * e.g., a blender is a "function"
#     * You put stuff into it
#     * Then push the button
#     * Altered stuff is returned to you
# * Some functions DO something, but don't compute a result
#     * `print()` is just such a function
# * Other functions compute a result and return (or give back) that result

# %% [markdown]
# Try typing `round(2.71)` into the cell below, but before you run it, try to guess what result will be computed and returned.

# %% [markdown]
# #### Food for thought
# Can you think of an appliance that performs the same function as a blender, but does not return anything to you afterwards?

# %% [markdown]
# #### What is a Function in Programming?
# * A function is a named snippet of *code* (program statements) that performs a specific task (e.g., outputting text to the screen) or computes/returns a result (e.g., `round(2.71)` returned 3)
#   * Some functions (e.g., `print()` and `round()`) are built in to programming languages and always available for us to use
#   * Every language ships with a set of these, the names differ but the idea doesn't
# * A function can be used in a program wherever that particular task/functionality is needed

# %% [markdown]
# Now let's put all of it to work.

# %% [markdown]
# ## Part 3: We Do and Wrap Up
#
# Time to put all of it to work.
#
# The first two exercises are algorithms only, written in plain English as comments, no code yet. An algorithm should be readable by someone who has never programmed.

# %% [markdown]
# ### Exercise 1
# Write an algorithm to compute the average of 3 exam scores.

# %%
# Exercise 1: algorithm for the average of 3 exam scores
# Write your steps here, in plain English, one per line.
# 1.
# 2.
# 3.

# %% [markdown]
# ### Exercise 2
# Write an algorithm to determine if a number is odd or even.

# %%
# Exercise 2: algorithm for deciding if a number is odd or even
# Write your steps here, in plain English, one per line.
# 1.
# 2.

# %% [markdown]
# ### Exercise 3
# Write a numerical expression to convert 72ºF to Celsius. Remember the *algorithm*, or *process*, for doing this:
# 1. Subtract 32 from the Fahrenheit temperature
# 2. Multiply the result by 5/9

# %%
# Exercise 3: convert 72 degrees Fahrenheit to Celsius
# Your expression here

# %% [markdown]
# ### Exercise 4
# Use `print()` to output a complete sentence.

# %%
# Exercise 4: print a complete sentence
# Your code here

# %% [markdown]
# ### Exercise 5
# Divide any two numbers, then use `round()` to round the result.

# %%
# Exercise 5: round the result of a division
# Your code here

# %% [markdown]
# ### Bonus
# The Exercise 2 algorithm probably says something like "check whether there's a remainder when dividing by 2." Write the expression that produces that remainder for the number 47.

# %%
# Bonus: is 47 odd or even?
# Your expression here

# %% [markdown]
# ### Wrap-Up
#
# Today, we:
# - Learned about navigating the Colab environment, executing code cells, and reading cell output
# - Learned what an algorithm is, and wrote a few of our own
# - Used the arithmetic operators, including exponentiation and modulus
# - Wrote our first program with `print()`, and read our first error message
# - Learned what a function is, and used two built-in ones: `print()` and `round()`
